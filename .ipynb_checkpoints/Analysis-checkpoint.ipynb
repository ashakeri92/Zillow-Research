# %% [markdown]
# # Zillow Research Analysis

# %% [markdown]
# by: Armun Shakeri

# %%
# Ideas for analysis

# 3 year, 5 year, and 10 year
# forecast housing prices 
# ROI, highest and lowest
# Median Sale Price

# %% [markdown]
# ## Overview and Business Problem

# %% [markdown]
# This project analyzes 3 bedroom homes in Texas to determine which 10 zipcodes had the highest ROI for 3, 5 and 10 year span.

# %% [markdown]
# ## Data Understanding

# %% [markdown]
# This data represents median monthly housing sales for 3 bedroom homes across the United States.
#
# Each row represents a unique ZipCode. Each record contains loccation info and median housing sales prices for each month.
#
# There are 23404 rows and 281 variables:
#
# RegionID: Unique index,
# <br />RegionName: Unique Zip Code,
# <br />City: City in which the zip code is located,
# <br />State: State in which the zip code is located,
# <br />Metro: Metropolitan Area in which the zip code is located,
# <br />CountyName: County in which the zip code is located,
# <br />SizeRank: Numerical rank of size of zip code, ranked 1 through 23404
# 01-00 through 08-22: refers to the median housing sales values for January 2000 through August 2022, that is 274 data points of monthly data for each zip code

# %% [markdown]
# ## Import standard packages and data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import itertools
import time
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv("Data/Zip_zhvi_bdrmcnt_3_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv")
data.head()
# Out:
#    RegionID  SizeRank  RegionName RegionType StateName State      City  \
# 0     91940         0       77449        zip        TX    TX       NaN
# 1     91982         1       77494        zip        TX    TX       NaN
# 2     93144         2       79936        zip        TX    TX   El Paso
# 3     62080         3       11368        zip        NY    NY  New York
# 4     62093         4       11385        zip        NY    NY  New York
#
#                                    Metro        CountyName     01-00  ...  \
# 0   Houston-The Woodlands-Sugar Land, TX     Harris County   96603.0  ...
# 1   Houston-The Woodlands-Sugar Land, TX  Fort Bend County  163540.0  ...
# 2                            El Paso, TX    El Paso County   87170.0  ...
# 3  New York-Newark-Jersey City, NY-NJ-PA     Queens County  324450.0  ...
# 4  New York-Newark-Jersey City, NY-NJ-PA     Queens County  279395.0  ...
#
#       11-21     12-21     01-22     02-22     03-22     04-22     05-22  \
# 0  232376.0  236021.0  239693.0  244103.0  249528.0  255561.0  261406.0
# 1  330128.0  334969.0  339733.0  346806.0  355476.0  365971.0  374539.0
# 2  167760.0  169442.0  171444.0  173448.0  175569.0  178832.0  182377.0
# 3  814606.0  815163.0  817786.0  818496.0  823195.0  827059.0  836542.0
# 4  749033.0  750202.0  754601.0  758353.0  764191.0  766694.0  772804.0
#
#       06-22     07-22     08-22
# 0  266140.0  269363.0  271087.0
# 1  379908.0  381471.0  380327.0
# 2  185780.0  188090.0  189856.0
# 3  842837.0  849412.0  852484.0
# 4  778368.0  783167.0  785138.0
#
# [5 rows x 281 columns]

# %% [markdown]
# Obtain information regarding data columns.

# %%
data.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23404 entries, 0 to 23403
# Data columns (total 281 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   RegionID    int64
#  1   SizeRank    int64
#  2   RegionName  int64
#  3   RegionType  object
#  4   StateName   object
#  5   State       object
#  6   City        object
#  7   Metro       object
#  8   CountyName  object
#  9   01-00       float64
#  10  02-00       float64
#  11  03-00       float64
#  12  04-00       float64
#  13  05-00       float64
#  14  06-00       float64
#  15  07-00       float64
#  16  08-00       float64
#  17  09-00       float64
#  18  10-00       float64
#  19  11-00       float64
#  20  12-00       float64
#  21  01-01       float64
#  22  02-01       float64
#  23  03-01       float64
#  24  04-01       float64
#  167 03-13       float64
#  168 04-13       float64
#  169 05-13       float64
#  170 06-13       float64
#  171 07-13       float64
#  172 08-13       float64
#  173 09-13       float64
#  174 10-13       float64
#  175 11-13       float64
#  176 12-13       float64
#  177 01-14       float64
#  178 02-14       float64
#  179 03-14       float64
#  180 04-14       float64
#  181 05-14       float64
#  182 06-14       float64
#  183 07-14       float64
#  184 08-14       float64
#  185 09-14       float64
#  186 10-14       float64
#  187 11-14       float64
#  188 12-14       float64
#  189 01-15       float64
#  190 02-15       float64
#  191 03-15       float64
#  192 04-15       float64
#  193 05-15       float64
#  194 06-15       float64
#  195 07-15       float64
#  196 08-15       float64
#  197 09-15       float64
#  198 10-15       float64
#  199 11-15       float64
#  200 12-15       float64
#  201 01-16       float64
#  202 02-16       float64
#  203 03-16       float64
#  204 04-16       float64
#  205 05-16       float64
#  206 06-16       float64
#  207 07-16       float64
#  208 08-16       float64
#  209 09-16       float64
#  210 10-16       float64
#  211 11-16       float64
#  212 12-16       float64
#  213 01-17       float64
#  214 02-17       float64
#  215 03-17       float64
#  216 04-17       float64
#  217 05-17       float64
#  218 06-17       float64
#  219 07-17       float64
#  220 08-17       float64
#  221 09-17       float64
#  222 10-17       float64
#  223 11-17       float64
#  224 12-17       float64
#  225 01-18       float64
#  226 02-18       float64
#  227 03-18       float64
#  228 04-18       float64
#  229 05-18       float64
#  230 06-18       float64
#  231 07-18       float64
#  232 08-18       float64
#  233 09-18       float64
#  234 10-18       float64
#  235 11-18       float64
#  236 12-18       float64
#  237 01-19       float64
#  238 02-19       float64
#  239 03-19       float64
#  240 04-19       float64
#  241 05-19       float64
#  242 06-19       float64
#  243 07-19       float64
#  244 08-19       float64
#  245 09-19       float64
#  246 10-19       float64
#  247 11-19       float64
#  248 12-19       float64
#  249 01-20       float64
#  250 02-20       float64
#  251 03-20       float64
#  252 04-20       float64
#  253 05-20       float64
#  254 06-20       float64
#  255 07-20       float64
#  256 08-20       float64
#  257 09-20       float64
#  258 10-20       float64
#  259 11-20       float64
#  260 12-20       float64
#  261 01-21       float64
#  262 02-21       float64
#  263 03-21       float64
#  264 04-21       float64
#  265 05-21       float64
#  266 06-21       float64
#  267 07-21       float64
#  268 08-21       float64
#  269 09-21       float64
#  270 10-21       float64
#  271 11-21       float64
#  272 12-21       float64
#  273 01-22       float64
#  274 02-22       float64
#  275 03-22       float64
#  276 04-22       float64
#  277 05-22       float64
#  278 06-22       float64
#  279 07-22       float64
#  280 08-22       float64
# dtypes: float64(272), int64(3), object(6)
# memory usage: 50.2+ MB

# %% [markdown]
# Drop all states outside of Texas.

# %%
data = data[data['State'] == 'TX']
data.head()
# Out:
#     RegionID  SizeRank  RegionName RegionType StateName State          City  \
# 0      91940         0       77449        zip        TX    TX           NaN
# 1      91982         1       77494        zip        TX    TX           NaN
# 2      93144         2       79936        zip        TX    TX       El Paso
# 7      91733         7       77084        zip        TX    TX       Houston
# 17     92593        17       78660        zip        TX    TX  Pflugerville
#
#                                    Metro        CountyName     01-00  ...  \
# 0   Houston-The Woodlands-Sugar Land, TX     Harris County   96603.0  ...
# 1   Houston-The Woodlands-Sugar Land, TX  Fort Bend County  163540.0  ...
# 2                            El Paso, TX    El Paso County   87170.0  ...
# 7   Houston-The Woodlands-Sugar Land, TX     Harris County   96608.0  ...
# 17      Austin-Round Rock-Georgetown, TX     Travis County  142867.0  ...
#
#        11-21     12-21     01-22     02-22     03-22     04-22     05-22  \
# 0   232376.0  236021.0  239693.0  244103.0  249528.0  255561.0  261406.0
# 1   330128.0  334969.0  339733.0  346806.0  355476.0  365971.0  374539.0
# 2   167760.0  169442.0  171444.0  173448.0  175569.0  178832.0  182377.0
# 7   227606.0  230914.0  234220.0  237989.0  242657.0  247697.0  252703.0
# 17  404382.0  415007.0  424494.0  435592.0  446426.0  455652.0  462620.0
#
#        06-22     07-22     08-22
# 0   266140.0  269363.0  271087.0
# 1   379908.0  381471.0  380327.0
# 2   185780.0  188090.0  189856.0
# 7   256619.0  259138.0  260480.0
# 17  458565.0  449787.0  438317.0
#
# [5 rows x 281 columns]

# %% [markdown]
# We will drop 'StateName' and 'RegionType' due to redundancy, and 'SizeRank' due to it being irrelevant for analysis.

# %%
data = data.drop(['StateName', 'RegionType', 'SizeRank'], axis=1)

# %% [markdown]
# We can see that there are 101,792 missing values within the dataset.

# %%
data.isna().sum().sum()
# Out:
# 101792

# %%
data.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1293 entries, 0 to 23400
# Data columns (total 278 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   RegionID    int64
#  1   RegionName  int64
#  2   State       object
#  3   City        object
#  4   Metro       object
#  5   CountyName  object
#  6   01-00       float64
#  7   02-00       float64
#  8   03-00       float64
#  9   04-00       float64
#  10  05-00       float64
#  11  06-00       float64
#  12  07-00       float64
#  13  08-00       float64
#  14  09-00       float64
#  15  10-00       float64
#  16  11-00       float64
#  17  12-00       float64
#  18  01-01       float64
#  19  02-01       float64
#  20  03-01       float64
#  21  04-01       float64
#  22  05-01       float64
#  23  06-01       float64
#  24  07-01       float64
#  25  08-01       float64
#  26  09-01       float64
#  27  10-01       float64
#  28  11-01       float64
#  29  12-01       float64
#  30  01-02       float64
#  31  02-02       float64
#  32  03-02       float64
#  33  04-02       float64
#  34  05-02       float64
#  35  06-02       float64
#  36  07-02       float64
#  37  08-02       float64
#  38  09-02       float64
#  39  10-02       float64
#  40  11-02       float64
#  41  12-02       float64
#  42  01-03       float64
#  43  02-03       float64
#  44  03-03       float64
#  45  04-03       float64
#  46  05-03       float64
#  47  06-03       float64
#  48  07-03       float64
#  49  08-03       float64
#  50  09-03       float64
#  51  10-03       float64
#  52  11-03       float64
#  53  12-03       float64
#  54  01-04       float64
#  55  02-04       float64
#  56  03-04       float64
#  57  04-04       float64
#  58  05-04       float64
#  59  06-04       float64
#  60  07-04       float64
#  61  08-04       float64
#  62  09-04       float64
#  63  10-04       float64
#  64  11-04       float64
#  65  12-04       float64
#  66  01-05       float64
#  67  02-05       float64
#  68  03-05       float64
#  69  04-05       float64
#  70  05-05       float64
#  71  06-05       float64
#  72  07-05       float64
#  73  08-05       float64
#  74  09-05       float64
#  75  10-05       float64
#  76  11-05       float64
#  77  12-05       float64
#  78  01-06       float64
#  221 12-17       float64
#  222 01-18       float64
#  223 02-18       float64
#  224 03-18       float64
#  225 04-18       float64
#  226 05-18       float64
#  227 06-18       float64
#  228 07-18       float64
#  229 08-18       float64
#  230 09-18       float64
#  231 10-18       float64
#  232 11-18       float64
#  233 12-18       float64
#  234 01-19       float64
#  235 02-19       float64
#  236 03-19       float64
#  237 04-19       float64
#  238 05-19       float64
#  239 06-19       float64
#  240 07-19       float64
#  241 08-19       float64
#  242 09-19       float64
#  243 10-19       float64
#  244 11-19       float64
#  245 12-19       float64
#  246 01-20       float64
#  247 02-20       float64
#  248 03-20       float64
#  249 04-20       float64
#  250 05-20       float64
#  251 06-20       float64
#  252 07-20       float64
#  253 08-20       float64
#  254 09-20       float64
#  255 10-20       float64
#  256 11-20       float64
#  257 12-20       float64
#  258 01-21       float64
#  259 02-21       float64
#  260 03-21       float64
#  261 04-21       float64
#  262 05-21       float64
#  263 06-21       float64
#  264 07-21       float64
#  265 08-21       float64
#  266 09-21       float64
#  267 10-21       float64
#  268 11-21       float64
#  269 12-21       float64
#  270 01-22       float64
#  271 02-22       float64
#  272 03-22       float64
#  273 04-22       float64
#  274 05-22       float64
#  275 06-22       float64
#  276 07-22       float64
#  277 08-22       float64
# dtypes: float64(272), int64(2), object(4)
# memory usage: 2.8+ MB

# %% [markdown]
# ## Analyze 'RegionID'

# %% [markdown]
# There are 1293 unique values within RegionID.

# %%
print(data.RegionID.value_counts())
print(data.RegionID.nunique())
print(data.RegionID.min())
print(data.RegionID.max())
# Out:
# 92157    1
# 90733    1
# 90759    1
# 92808    1
# 90761    1
#         ..
# 91392    1
# 91395    1
# 91397    1
# 91398    1
# 92160    1
# Name: RegionID, Length: 1293, dtype: int64
# 1293
# 90611
# 787971

# %% [markdown]
# Doesn't mean anything and all are unique so we will change the astype to string.

# %%
data.RegionID = data.RegionID.astype('string')

# %% [markdown]
# ## Analyze 'RegionName'

# %% [markdown]
# Next we will look at RegionName, this is the zip code. We can see that there are 419 unique values.

# %%
data.RegionName.value_counts()
# Out:
# 77880    1
# 76437    1
# 76476    1
# 78526    1
# 76085    1
#         ..
# 78933    1
# 79226    1
# 77657    1
# 75134    1
# 77563    1
# Name: RegionName, Length: 1293, dtype: int64

# %% [markdown]
# All zipcodes are unique. I will change the astype to string.

# %%
data.RegionName = data.RegionName.astype('string')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1293 entries, 0 to 23400
# Columns: 278 entries, RegionID to 08-22
# dtypes: float64(272), object(4), string(2)
# memory usage: 2.8+ MB

# %%
data[['RegionName', 'State']].sort_values(by=['RegionName'])
# Out:
#      RegionName State
# 7529      75001    TX
# 142       75002    TX
# 768       75006    TX
# 571       75007    TX
# 6689      75009    TX
# ...         ...   ...
# 3745      79932    TX
# 4607      79934    TX
# 7240      79935    TX
# 2         79936    TX
# 97        79938    TX
#
# [1293 rows x 2 columns]

# %% [markdown]
# ## Analyze 'City'

# %%
data.City.nunique()
# Out:
# 701

# %%
data.City.isna().sum()
# Out:
# 102

# %%
data.City.fillna('None', inplace=True)

# %% [markdown]
# ## Analyze 'Metro'

# %% [markdown]
# Fillna with None

# %%
print(data.Metro.value_counts())
print(data.Metro.nunique())
# Out:
# Dallas-Fort Worth-Arlington, TX         249
# Houston-The Woodlands-Sugar Land, TX    213
# San Antonio-New Braunfels, TX            94
# Austin-Round Rock-Georgetown, TX         83
# El Paso, TX                              26
#                                        ...
# Raymondville, TX                          1
# Pecos, TX                                 1
# Snyder, TX                                1
# Andrews, TX                               1
# Lamesa, TX                                1
# Name: Metro, Length: 71, dtype: int64
# 71

# %%
data.Metro.fillna('None', inplace=True)

# %%
data.Metro.value_counts()
# Out:
# Dallas-Fort Worth-Arlington, TX         249
# Houston-The Woodlands-Sugar Land, TX    213
# None                                    189
# San Antonio-New Braunfels, TX            94
# Austin-Round Rock-Georgetown, TX         83
#                                        ...
# Rio Grande City-Roma, TX                  1
# Vernon, TX                                1
# Lamesa, TX                                1
# Pearsall, TX                              1
# Hereford, TX                              1
# Name: Metro, Length: 72, dtype: int64

# %% [markdown]
# ## Analyze 'CountyName'

# %%
data.CountyName.value_counts()
# Out:
# Harris County       129
# Dallas County        77
# Bexar County         65
# Tarrant County       63
# Travis County        45
#                    ...
# Childress County      1
# Scurry County         1
# Hartley County        1
# Mitchell County       1
# Winkler County        1
# Name: CountyName, Length: 206, dtype: int64

# %%
data.isna().sum()
# Out:
# RegionID       0
# RegionName     0
# State          0
# City           0
# Metro          0
#               ..
# 04-22         16
# 05-22         13
# 06-22          6
# 07-22          4
# 08-22          0
# Length: 278, dtype: int64

# %%
data.CountyName.fillna('None', inplace=True)

# %% [markdown]
# ## Drop sales data that have missing values

# %% [markdown]
# We will need to drop all sales data that are missing sales values since we will not be able to use them for analysis.

# %%
# data = data.dropna()

# %%
# 760 zip codes don't have full data
data[data['01-00'].isna()]
# Out:
#       RegionID RegionName State           City  \
# 32       92481      78521    TX    Brownsville
# 50       92036      77573    TX    League City
# 86       92598      78666    TX     San Marcos
# 87       92515      78572    TX        Mission
# 93       92271      78130    TX  New Braunfels
# ...        ...        ...   ...            ...
# 23278    91965      77476    TX       Simonton
# 23325    92918      79350    TX       New Deal
# 23371    92177      77978    TX  Point Comfort
# 23372    92087      77663    TX  Village Mills
# 23400    91942      77451    TX   East Bernard
#
#                                       Metro        CountyName  01-00  02-00  \
# 32                Brownsville-Harlingen, TX    Cameron County    NaN    NaN
# 50     Houston-The Woodlands-Sugar Land, TX  Galveston County    NaN    NaN
# 86         Austin-Round Rock-Georgetown, TX       Hays County    NaN    NaN
# 87             McAllen-Edinburg-Mission, TX    Hidalgo County    NaN    NaN
# 93            San Antonio-New Braunfels, TX      Comal County    NaN    NaN
# ...                                     ...               ...    ...    ...
# 23278  Houston-The Woodlands-Sugar Land, TX  Fort Bend County    NaN    NaN
# 23325                           Lubbock, TX    Lubbock County    NaN    NaN
# 23371                       Port Lavaca, TX    Calhoun County    NaN    NaN
# 23372              Beaumont-Port Arthur, TX     Hardin County    NaN    NaN
# 23400  Houston-The Woodlands-Sugar Land, TX  Fort Bend County    NaN    NaN
#
#        03-00  04-00  ...     11-21     12-21     01-22     02-22     03-22  \
# 32       NaN    NaN  ...  141332.0  143702.0  145785.0  148925.0  151875.0
# 50       NaN    NaN  ...  290825.0  294876.0  297864.0  301136.0  305735.0
# 86       NaN    NaN  ...  347549.0  354405.0  362174.0  372118.0  378769.0
# 87       NaN    NaN  ...  155467.0  157316.0  159385.0  161236.0  163578.0
# 93       NaN    NaN  ...  306869.0  313174.0  320356.0  326121.0  333881.0
# ...      ...    ...  ...       ...       ...       ...       ...       ...
# 23278    NaN    NaN  ...       NaN       NaN       NaN       NaN       NaN
# 23325    NaN    NaN  ...  107664.0  108907.0  110654.0  113874.0  114829.0
# 23371    NaN    NaN  ...  115988.0  118425.0  120843.0  123808.0  124556.0
# 23372    NaN    NaN  ...  195445.0  197359.0  200307.0  202782.0  204581.0
# 23400    NaN    NaN  ...       NaN       NaN       NaN       NaN       NaN
#
#           04-22     05-22     06-22     07-22     08-22
# 32     155071.0  157557.0  160752.0  163829.0  167074.0
# 50     312295.0  317528.0  320674.0  321755.0  323265.0
# 86     385599.0  387554.0  389007.0  386720.0  383152.0
# 87     165853.0  168492.0  171377.0  174236.0  177440.0
# 93     342038.0  349460.0  354485.0  356144.0  357161.0
# ...         ...       ...       ...       ...       ...
# 23278       NaN  385388.0  389306.0  390118.0  389159.0
# 23325  117038.0  117008.0  118964.0  120559.0  121161.0
# 23371  125456.0  125696.0  127545.0  129641.0  132003.0
# 23372  206977.0  209768.0  213646.0  216736.0  219361.0
# 23400       NaN  211125.0  211719.0  210235.0  205233.0
#
# [760 rows x 278 columns]

# %%
# All zipcodes have some data
data[data['08-22'].isna()]
# Out:
# Empty DataFrame
# Columns: [RegionID, RegionName, State, City, Metro, CountyName, 01-00, 02-00, 03-00, 04-00, 05-00, 06-00, 07-00, 08-00, 09-00, 10-00, 11-00, 12-00, 01-01, 02-01, 03-01, 04-01, 05-01, 06-01, 07-01, 08-01, 09-01, 10-01, 11-01, 12-01, 01-02, 02-02, 03-02, 04-02, 05-02, 06-02, 07-02, 08-02, 09-02, 10-02, 11-02, 12-02, 01-03, 02-03, 03-03, 04-03, 05-03, 06-03, 07-03, 08-03, 09-03, 10-03, 11-03, 12-03, 01-04, 02-04, 03-04, 04-04, 05-04, 06-04, 07-04, 08-04, 09-04, 10-04, 11-04, 12-04, 01-05, 02-05, 03-05, 04-05, 05-05, 06-05, 07-05, 08-05, 09-05, 10-05, 11-05, 12-05, 01-06, 02-06, 03-06, 04-06, 05-06, 06-06, 07-06, 08-06, 09-06, 10-06, 11-06, 12-06, 01-07, 02-07, 03-07, 04-07, 05-07, 06-07, 07-07, 08-07, 09-07, 10-07, ...]
# Index: []
#
# [0 rows x 278 columns]

# %%
We will need to find an ROI that we can compare all of them on, nex

# %%
# I need to find an ROI that I can compare them all on
# Find the zips with the least data
for col in reversed(data.columns):
    if data[col].isna().sum() > 0:
        print(col)
        break
# Out:
# 07-22

# %%
# 4 zip codes only go back to 07-22
data[data['07-22'].isna()]
# Out:
#       RegionID RegionName State     City               Metro       CountyName  \
# 17345    92880      79241    TX  Lockney                None     Floyd County
# 18952    91593      76853    TX   Lometa  Killeen-Temple, TX  Lampasas County
# 20796    91622      76890    TX   Zephyr       Brownwood, TX     Brown County
# 22736    93016      79563    TX      Tye         Abilene, TX    Taylor County
#
#        01-00  02-00  03-00  04-00  ...  11-21  12-21  01-22  02-22  03-22  \
# 17345    NaN    NaN    NaN    NaN  ...    NaN    NaN    NaN    NaN    NaN
# 18952    NaN    NaN    NaN    NaN  ...    NaN    NaN    NaN    NaN    NaN
# 20796    NaN    NaN    NaN    NaN  ...    NaN    NaN    NaN    NaN    NaN
# 22736    NaN    NaN    NaN    NaN  ...    NaN    NaN    NaN    NaN    NaN
#
#        04-22  05-22  06-22  07-22     08-22
# 17345    NaN    NaN    NaN    NaN  104651.0
# 18952    NaN    NaN    NaN    NaN  201628.0
# 20796    NaN    NaN    NaN    NaN  284145.0
# 22736    NaN    NaN    NaN    NaN  117520.0
#
# [4 rows x 278 columns]

# %% [markdown]
# ## EDA on ZipCodes

# %%
# Check out most recent 1 year ROI
data['recent_1_yr_ROI'] = (data['08-22'] - data['08-21'])/(data['08-21'])
data['recent_1_yr_ROI']
# Out:
# 0        0.232488
# 1        0.219513
# 2        0.182189
# 7        0.207553
# 17       0.123829
#            ...
# 23325    0.175567
# 23352    0.179743
# 23371    0.169669
# 23372    0.145991
# 23400         NaN
# Name: recent_1_yr_ROI, Length: 1293, dtype: float64

# %%
# Lowest Values
data.sort_values('recent_1_yr_ROI').head()[['RegionName', 'City', 'recent_1_yr_ROI']]
# Out:
#       RegionName      City  recent_1_yr_ROI
# 5133       79764    Odessa        -0.005129
# 10220      75758  Chandler        -0.000207
# 20091      75928  Bon Wier         0.000621
# 16286      77335      None         0.000758
# 23155      78549   Hargill         0.002249

# %%
# Highest Values 
data.sort_values('recent_1_yr_ROI', ascending=False).head()[['RegionName', 'City', 'recent_1_yr_ROI']]
# Out:
#       RegionName       City  recent_1_yr_ROI
# 18276      78615   Coupland         0.487145
# 6514       76541    Killeen         0.416958
# 14058      76066       None         0.402902
# 17560      75058     Gunter         0.391927
# 11436      78583  Rio Hondo         0.377453

# %%
# Find avg ROI for the past 3 years 
def average_one_year_ROI(df):
    average_one_year_ROI = []
    for i in range(len(df)):
        year_1_ROI = df['recent_1_yr_ROI'][i]
        year_2_ROI = (df.iloc[i,-15] - df.iloc[i,-27])/df.iloc[i,-27]
        year_3_ROI = (df.iloc[i,-27] - df.iloc[i,-39])/df.iloc[i,-39]
        avg_ROI = (year_1_ROI + year_2_ROI + year_3_ROI)/3
        average_one_year_ROI.append(avg_ROI)
    return average_one_year_ROI

# %%
data['avg_one_yr_ROI'] = average_one_year_ROI(data)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 3
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-35-c52fecbf06bc> in <module>
# ----> 1 data['avg_one_yr_ROI'] = average_one_year_ROI(data)
#
# <ipython-input-34-987b86efacda> in average_one_year_ROI(df)
#       3     average_one_year_ROI = []
#       4     for i in range(len(df)):
# ----> 5         year_1_ROI = df['recent_1_yr_ROI'][i]
#       6         year_2_ROI = (df.iloc[i,-15] - df.iloc[i,-27])/df.iloc[i,-27]
#       7         year_3_ROI = (df.iloc[i,-27] - df.iloc[i,-39])/df.iloc[i,-39]
#
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/series.py in __getitem__(self, key)
#     880
#     881         elif key_is_scalar:
# --> 882             return self._get_value(key)
#     883
#     884         if is_hashable(key):
#
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/series.py in _get_value(self, label, takeable)
#     987
#     988         # Similar to Index.get_value, but we do not fall back to positional
# --> 989         loc = self.index.get_loc(label)
#     990         return self.index._get_values_for_loc(self, loc, label)
#     991
#
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 3
